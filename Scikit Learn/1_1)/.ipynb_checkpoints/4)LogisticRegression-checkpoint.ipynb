# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

# %%
l = LogisticRegression()
l?

# %%
sgd = SGDClassifier()
sgd?

# %% [markdown]
# # L1 Penalty and Sparsity in Logistic Regression

# %% [markdown]
# Comparision of sparsity. i.e. percentage of zero coefficients.
# for L1 and L2 Penalization for differeent value of C.

# %% [markdown]
# #### Import Statements

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
s = "\nDone(*_*)"
print(s)
# Out:
# Done(*_*)

# %% [markdown]
# #### Loading data

# %%
data = load_digits()

X,y = data.data,data.target

print(X.shape)
print(y)
print(s)
# Out:
# (1797, 64)
# [0 1 2 ..., 8 9 8]
#
# Done(*_*)

# %% [markdown]
# #### Transforming data

# %%
X = StandardScaler().fit_transform(X)
y_ = ( y > 4).astype(np.int)

#print(y_[800:])
print(s)
# Out:
# Done(*_*)

# %% [markdown]
# #### Fitting model

# %%
for i, C in enumerate(range(1,10,1)):
    clf_l1 = LogisticRegression(C=C,penalty="l1")
    clf_l2 = LogisticRegression(C=C,penalty='l2')
    clf_l1 = clf_l1.fit(X,y_)
    clf_l2 = clf_l2.fit(X,y_)
    sparcity1 = np.mean(clf_l1.coef_.ravel() == 0)*100
    sparcity2 = np.mean(clf_l2.coef_.ravel() == 0)*100
    fig, ax = plt.subplots(2,2)
    plt.subplot(2,3,1)
    plt.imshow(np.abs(clf_l1.coef_.ravel().reshape(8,8)),interpolation="nearest")
    plt.subplot(2,3,6)
    plt.imshow(np.abs(clf_l2.coef_.ravel().reshape(8,8)),interpolation="nearest")
    plt.colorbar(orientation="horizontal")
    plt.title("Cl1: "+str(clf_l1.C)+" Cl2: "+str(clf_l2.C)+ " Sparcityl1: "+str(sparcity1)+" Sparcityl2: "+str(sparcity2))
    plt.show()
