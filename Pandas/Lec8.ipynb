# %%
import pandas as pd
import matplotlib.pyplot as plt
import quandl
import numpy as np
print("Done")
# Out:
# Done

# %%
## df contains original data

path = 'C:\\Users\\Aman\\Desktop\\OtherFolders\\Sem7\\Topics Of Study\\Python\\Pandas'
df = pd.read_pickle(path+"\\FMAC_HPI.pickle")
#print(df)

# %%
## plotting original data
df.plot()
plt.legend().remove()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     225
#     226     if 'png' in formats:
# --> 227         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     228     if 'retina' in formats or 'png2x' in formats:
#     229         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
##percent change

# selecting the numeric data
df_pct = df.select_dtypes(include=[np.number]).pct_change()
#print(df_pct)

#plotting the same
df_pct.plot()
plt.legend().remove()
plt.show()

# %%
## printing coloumns
print(df_pct.columns)
# Out:
# Index(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
#        'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
#        'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA',
#        'WI', 'WV', 'WY', 'United States not seasonaly adjusted',
#        'United States seasonaly adjusted'],
#       dtype='object')

# %%
# plotting only one column
df['AK'].pct_change().plot()
plt.show()

# %%
## plotting each column individually
for item in df.columns[1:]:
    df[item].pct_change().plot()
    plt.show()

# %%
print(df['AK'][0])
# Out:
# 34.527917546

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((1,1),(0,0))

# %%
## taking percentage from first row

for col in df.columns[1:]:
    df[col] = (df[col] - df[col][0])/df[col][0]*100.0


df.plot()
plt.legend().remove()
plt.show()

# %%
## getting bench mark data from quandl and pickling it

HPI_USA = quandl.get("FMAC/HPI_USA")
##pd.to_csv(path+"\\FMAC/HPI_USA.csv")
HPI_USA.to_pickle(path+"\\FMAC_HPI_USA.pickle")
#print(HPI_USA)

# %%
##loading benchmark data from FMAC_HPI_USA
HPI_USA = pd.read_pickle(path+"\\FMAC_HPI_USA.pickle")
print(HPI_USA.head())
# Out:
#                 Value
# Date
# 1975-01-31  23.424665
# 1975-02-28  23.576738
# 1975-03-31  23.827713
# 1975-04-30  24.154570
# 1975-05-31  24.354313

# %%
print(HPI_USA.columns)
print((HPI_USA['Value']-HPI_USA['Value'][0])/HPI_USA['Value'][0]*100.0)
# Out:
# Index(['Value'], dtype='object')
# Date
# 1975-01-31      0.000000
# 1975-02-28      0.649201
# 1975-03-31      1.720612
# 1975-04-30      3.115969
# 1975-05-31      3.968672
# 1975-06-30      4.142241
# 1975-07-31      4.378851
# 1975-08-31      4.799540
# 1975-09-30      5.175557
# 1975-10-31      5.517447
# 1975-11-30      6.001757
# 1975-12-31      6.635380
# 1976-01-31      7.284305
# 1976-02-29      7.952588
# 1976-03-31      8.893802
# 1976-04-30     10.106826
# 1976-05-31     10.985126
# 1976-06-30     11.586061
# 1976-07-31     12.347057
# 1976-08-31     13.095691
# 1976-09-30     13.708951
# 1976-10-31     14.351743
# 1976-11-30     15.215677
# 1976-12-31     16.105013
# 1977-01-31     16.944354
# 1977-02-28     17.966513
# 1977-03-31     19.528672
# 1977-04-30     21.719458
# 1977-05-31     23.621577
# 1977-06-30     24.965030
#                  ...
# 2015-04-30    554.609531
# 2015-05-31    562.918019
# 2015-06-30    569.614097
# 2015-07-31    573.508945
# ...

# %%
## percent change in benchmark
HPI_USA['Value'] = (HPI_USA['Value']-HPI_USA['Value'][0])/HPI_USA['Value'][0]*100.0
print(HPI_USA.head())
# Out:
#                Value
# Date
# 1975-01-31  0.000000
# 1975-02-28  0.649201
# 1975-03-31  1.720612
# 1975-04-30  3.115969
# 1975-05-31  3.968672

# %%
#HPI_USA.plot(ax=ax1,color='k',linewidth=10)
HPI_USA.plot(ax=ax1)

#plt.legend().remove()
plt.show()
print("Done")
# Out:
# Done

# %%
ax = df.plot()
plt.legend().remove()
HPI_USA.plot(color='k',linewidth=10)
plt.legend().remove()
plt.show()

# %%
## correlating different states
corr_data = df.corr()
plt.scatter(x=corr_data['AK'],y=corr_data['AR'])
plt.show()

# %%
## descibing the corr_data dataframe
print(corr_data.describe())
# Out:
#               AK         AL         AR         AZ         CA         CO  \
# count  53.000000  53.000000  53.000000  53.000000  53.000000  53.000000
# mean    0.943499   0.969277   0.971721   0.937791   0.950414   0.952082
# std     0.039212   0.026058   0.025311   0.026356   0.023235   0.029560
# min     0.785736   0.881332   0.870650   0.860392   0.876620   0.847378
# 25%     0.934630   0.956681   0.967069   0.923813   0.937746   0.939954
# 50%     0.954402   0.977734   0.978579   0.939055   0.948725   0.958097
# 75%     0.964597   0.985692   0.987145   0.950906   0.964725   0.972870
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               CT         DC         DE         FL  \
# count  53.000000  53.000000  53.000000  53.000000
# mean    0.927490   0.927038   0.962463   0.934507
# std     0.040693   0.043325   0.028659   0.029460
# min     0.816186   0.755189   0.871262   0.849449
# 25%     0.898814   0.915527   0.950768   0.917059
# ...
