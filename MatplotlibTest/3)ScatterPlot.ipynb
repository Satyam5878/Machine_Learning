# %%
import matplotlib.pyplot as plt
import random
x = [x for x in range(0,10)]
y = [int(random.random()*10+1) for x in range(0,10)]

plt.scatter(x,y,label="Scatter Plot",color="r",marker="*",s = 50)



plt.show()
