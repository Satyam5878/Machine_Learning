# %%
import matplotlib.pyplot as plt
import math
print("Aman")
# Out:
# Aman

# %%
x = range(0,20)
y = range(0,20)

z = range(-20,40,2)
a = range(-20,40,2)

plt.plot(x,y,label="first plot")
plt.plot(a,z,label="second plot")

plt.legend()
plt.show()
